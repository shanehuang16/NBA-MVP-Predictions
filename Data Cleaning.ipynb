# %%
import pandas as pd
import numpy as np

# %%
year = 2020

mvp_urlparts = ['https://www.basketball-reference.com/awards/awards_',str(year),'.html']
mvp_url = "".join(mvp_urlparts)

team_urlparts = ['https://www.basketball-reference.com/leagues/NBA_',str(year),'_standings.html']
team_url = "".join(team_urlparts)

# %%
mvp_dfs = pd.read_html(mvp_url)
team_dfs = pd.read_html(team_url)

# %%
mvp = mvp_dfs[0]
mvp.columns = mvp.columns.get_level_values(1)
mvp['Year'] = year

# %%
mvp
# Out:
#     Rank                 Player  Age   Tm  First  Pts Won  Pts Max  Share   G  \
# 0      1  Giannis Antetokounmpo   25  MIL   85.0    962.0     1010  0.952  63
# 1      2           LeBron James   35  LAL   16.0    753.0     1010  0.746  67
# 2      3           James Harden   30  HOU    0.0    367.0     1010  0.363  68
# 3      4            Luka Dončić   20  DAL    0.0    200.0     1010  0.198  61
# 4      5          Kawhi Leonard   28  LAC    0.0    168.0     1010  0.166  57
# 5      6          Anthony Davis   26  LAL    0.0     82.0     1010  0.081  62
# 6      7             Chris Paul   34  OKC    0.0     26.0     1010  0.026  70
# 7      8         Damian Lillard   29  POR    0.0     23.0     1010  0.023  66
# 8      9           Nikola Jokić   24  DEN    0.0     18.0     1010  0.018  73
# 9     10          Pascal Siakam   25  TOR    0.0     17.0     1010  0.017  60
# 10    11           Jimmy Butler   30  MIA    0.0      9.0     1010  0.009  58
# 11    12           Jayson Tatum   21  BOS    0.0      1.0     1010  0.001  66
#
#       MP  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  Year
# 0   30.4  ...  13.6   5.6  1.0  1.0  0.553  0.304  0.633  11.1  0.279  2020
# 1   34.6  ...   7.8  10.2  1.2  0.5  0.493  0.348  0.693   9.8  0.204  2020
# 2   36.5  ...   6.6   7.5  1.8  0.9  0.444  0.355  0.865  13.1  0.254  2020
# 3   33.6  ...   9.4   8.8  1.0  0.2  0.463  0.316  0.758   8.8  0.207  2020
# 4   32.4  ...   7.1   4.9  1.8  0.6  0.470  0.378  0.886   8.7  0.226  2020
# 5   34.4  ...   9.3   3.2  1.5  2.3  0.503  0.330  0.846  11.1  0.250  2020
# 6   31.5  ...   5.0   6.7  1.6  0.2  0.489  0.365  0.907   8.9  0.193  2020
# 7   37.5  ...   4.3   8.0  1.1  0.3  0.463  0.401  0.888  11.6  0.225  2020
# 8   32.0  ...   9.7   7.0  1.2  0.6  0.528  0.314  0.817   9.8  0.202  2020
# 9   35.2  ...   7.3   3.5  1.0  0.9  0.453  0.359  0.792   5.4  0.123  2020
# 10  33.8  ...   6.7   6.0  1.8  0.6  0.455  0.244  0.834   9.0  0.221  2020
# 11  34.3  ...   7.0   3.0  1.4  0.9  0.450  0.403  0.812   6.9  0.146  2020
#
# [12 rows x 21 columns]

# %%
team_e = team_dfs[0]
team_w = team_dfs[1]
team_e.rename(columns={team_e.columns[0]: "Team Name"}, inplace=True)
team_w.rename(columns={team_w.columns[0]: "Team Name"}, inplace=True)

team = pd.concat([team_e,team_w]).reset_index(drop=True)

team.iloc[:,0] = team.iloc[:,0].str.replace('*','')
team = team.iloc[:,[0,3,7]]

team['Year'] = year

# %%
team
# Out:
#                  Team Name   W/L%   SRS  Year
# 0          Milwaukee Bucks  0.767  9.41  2020
# 1          Toronto Raptors  0.736  5.97  2020
# 2           Boston Celtics  0.667  5.83  2020
# 3           Indiana Pacers  0.616  1.63  2020
# 4               Miami Heat  0.603  2.59  2020
# 5       Philadelphia 76ers  0.589  2.25  2020
# 6            Brooklyn Nets  0.486 -1.01  2020
# 7            Orlando Magic  0.452 -0.93  2020
# 8        Charlotte Hornets  0.354 -7.03  2020
# 9       Washington Wizards  0.347 -5.24  2020
# 10           Chicago Bulls  0.338 -4.00  2020
# 11         New York Knicks  0.318 -6.72  2020
# 12         Detroit Pistons  0.303 -4.38  2020
# 13           Atlanta Hawks  0.299 -7.71  2020
# 14     Cleveland Cavaliers  0.292 -7.77  2020
# 15      Los Angeles Lakers  0.732  6.28  2020
# 16    Los Angeles Clippers  0.681  6.66  2020
# 17          Denver Nuggets  0.630  2.35  2020
# 18         Houston Rockets  0.611  3.13  2020
# 19   Oklahoma City Thunder  0.611  2.33  2020
# 20               Utah Jazz  0.611  2.52  2020
# 21        Dallas Mavericks  0.573  4.87  2020
# 22  Portland Trail Blazers  0.473 -0.61  2020
# 23       Memphis Grizzlies  0.466 -0.91  2020
# 24            Phoenix Suns  0.466  0.56  2020
# 25       San Antonio Spurs  0.451 -0.65  2020
# 26        Sacramento Kings  0.431 -1.59  2020
# 27    New Orleans Pelicans  0.417 -0.55  2020
# 28  Minnesota Timberwolves  0.297 -4.02  2020
# 29   Golden State Warriors  0.231 -8.12  2020
